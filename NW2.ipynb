# %% [markdown]
# <a href="https://colab.research.google.com/github/shudaGutHub/saleem-andrew/blob/master/NW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#UpLoad "df_train_HOU_2014.csv"
datafile =  "NW2_df_train_winners.csv"
df = pd.read_csv(datafile, nrows=10)
#

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 297 columns):
# runner_id                                    object
# race_id                                      object
# x8name                                       object
# jcp_track_sym                                object
# date                                         object
# race_race_num                                int64
# program_post_pos                             int64
# runner_entry                                 float64
# race_distance                                int64
# race_surface                                 object
# race_time                                    object
# race_race_type                               object
# race_age_sex_restriction                     object
# race_race_classification                     object
# race_purse                                   int64
# race_claiming_price_race                     float64
# ...

# %%
cols_time = ["race_f1_time",
             "race_f2_time",
             "race_f3_time",
             "race_f4_time",
             "race_winning_time"]

cols_pos =["post_position",                                
            "pos_call_start",                               
            "pos_call_1",                                   
            "pos_call_2",                                   
            "pos_call_3",                                   
            "pos_call_4",                                   
            "pos_call_stretch",                             
            "pos_call_finish",                             
            "official_finish_position",                    
            "call_1_lengths_behind",                        
            "call_2_lengths_behind",                        
            "call_3_lengths_behind",                        
            "call_4_lengths_behind",                        
            "stretch_call_lengths_behind",                  
            "finish_lengths_behind"]          
            
cols_racecondition =['date','race_id','race_age_sex_restriction',
                     'is_restricted_to_statebred',
                     'race_race_type',
                     'race_purse',
                     'race_claiming_price_race',
                     'race_race_classification',
                     'race_race_conditions',
                     'apprentice_weight_allowance']
cols_observable = ['race_distance',
                   'distance',
                   'race_pace_HDW_par_2f_level',
                   'race_pace_HDW_par_4f_level',
                   'race_speed_HDW_par_class_level',
                   'race_pace_HDW_par_6f_level',
                   'race_pace_HDW_par_late_level',
                   'days_since_last_race',
                   'race_surface',
                   'is_route']

# %%
df[race_comdicols_pos]
# Out:
#    post_position  ...  finish_lengths_behind
# 0            9.0  ...                    NaN
# 1            4.0  ...                    NaN
# 2            7.0  ...                    NaN
# 3            7.0  ...                    NaN
# 4            5.0  ...                    NaN
# 5            3.0  ...                    NaN
# 6            1.0  ...                    NaN
# 7            5.0  ...                    NaN
# 8            2.0  ...                    NaN
# 9            4.0  ...                    NaN
#
# [10 rows x 15 columns]
